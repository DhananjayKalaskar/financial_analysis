# %% [markdown]
# # 1. PANDAS BASICS

# %%
# Pandas is a data manipulation and analysis tool that is built on Numpy.
# Pandas uses a data structure known as DataFrame (think of it as Microsoft excel in Python). 
# DataFrames empower programmers to store and manipulate data in a tabular fashion (rows and columns).
# Series Vs. DataFrame? Series is considered a single column of a DataFrame.

# %%
import pandas as pd

# %%
# Let's define two lists as shown below:
my_list=["AAPL","AMZN",'T']

# %%
label = ['stock1','stock2','stock3']

# %%
print(type(label))
# Out:
# <class 'list'>

# %%
# Let's create a one dimensional Pandas "series" 
# Note that series is formed of data and associated labels 
x_series = pd.Series(data = my_list, index=label)

# %%
# Let's view the series
x_series
# Out:
# stock1    AAPL
# stock2    AMZN
# stock3       T
# dtype: object

# %%
# Let's obtain the datatype
type(x_series)
# Out:
# pandas.core.series.Series

# %%
# Let's define a two-dimensional Pandas DataFrame
# Note that you can create a pandas dataframe from a python dictionary
bank_client_df = pd.DataFrame({"Bank_clint_id":[111,22,33,444],
                                "Bank_client_name":["Chanel","Steve","Mitch","Ryan"],
                                "Net_worth[$]":[3500,29000,10000,2000],
                                "Year_with_bank":[3,4,9,5] })

# %%
bank_client_df
# Out:
#    Bank_clint_id Bank_client_name  Net_worth[$]  Year_with_bank
# 0            111           Chanel          3500               3
# 1             22            Steve         29000               4
# 2             33            Mitch         10000               9
# 3            444             Ryan          2000               5

# %%
# Let's obtain the data type 
type(bank_client_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# you can only view the first couple of rows using .head()
bank_client_df.head(2)
# Out:
#    Bank_clint_id Bank_client_name  Net_worth[$]  Year_with_bank
# 0            111           Chanel          3500               3
# 1             22            Steve         29000               4

# %%
# you can only view the last couple of rows using .tail()
bank_client_df.tail()
# Out:
#    Bank_clint_id Bank_client_name  Net_worth[$]  Year_with_bank
# 0            111           Chanel          3500               3
# 1             22            Steve         29000               4
# 2             33            Mitch         10000               9
# 3            444             Ryan          2000               5

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **A porfolio contains a collection of securities such as stocks, bonds and ETFs. Define a dataframe named 'portfolio_df' that holds 3 different stock ticker symbols, number of shares, and price per share (feel free to choose any stocks)**
# - **Calculate the total value of the porfolio including all stocks**

# %%
portfolio_df =pd.DataFrame({"Stock_name":["AAPL","AMZN","T"],
                            "number_of_shares":[5,9,10],
                            "price_per_share":[3000,2500,4000]})

# %%
portfolio_df
# Out:
#   Stock_name  number_of_shares  price_per_share
# 0       AAPL                 5             3000
# 1       AMZN                 9             2500
# 2          T                10             4000

# %%
stocks_dollar_value =portfolio_df["number_of_shares"]*portfolio_df["price_per_share"]
print(stocks_dollar_value)
print('Toatl_portfolio_value={}'.format(stocks_dollar_value.sum()))
# Out:
# 0    15000
# 1    22500
# 2    40000
# dtype: int64
# Toatl_portfolio_value=77500

# %% [markdown]
# # 2. PANDAS WITH CSV AND HTML DATA

# %%
# Pandas is used to read a csv file and store data in a DataFrame
import pandas as pd

bank_df = pd.read_csv('bank_client_information.csv')

# %%
bank_df
# Out:
#   First Name Last Name              Email Postal Code   Net Worth
# 0     Joseph    Patton     daafeja@boh.jm     M6U 5U7  $2,629.13
# 1       Noah     Moran  guutodi@bigwoc.kw     K2D 4M9  $8,626.96
# 2       Nina    Keller    azikez@gahew.mr     S1T 4E6  $9,072.02

# %%
# write to a csv file without an index
bank_df.to_csv('sample_output.csv',index = False)

# %%
# write to a csv file with an index
bank_df.to_csv('sample_output.csv',index = True)

# %%
# Read tabular data using read_html
house_prices_df =pd.read_html('https://www.livingin-canada.com/house-prices-canada.html', flavor='html5lib')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# d:\financial_analysis\8. Python 101 - Python Libraries for Data Analysis - Pandas Skeleton.ipynb Cell 24' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/financial_analysis/8.%20Python%20101%20-%20Python%20Libraries%20for%20Data%20Analysis%20-%20Pandas%20Skeleton.ipynb#ch0000023?line=0'>1</a> # Read tabular data using read_html
# ----> <a href='vscode-notebook-cell:/d%3A/financial_analysis/8.%20Python%20101%20-%20Python%20Libraries%20for%20Data%20Analysis%20-%20Pandas%20Skeleton.ipynb#ch0000023?line=1'>2</a> house_prices_df =pd.read_html('https://www.livingin-canada.com/house-prices-canada.html', flavor='html5lib')
#
# File ~\anaconda3\envs\ds\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File ~\anaconda3\envs\ds\lib\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1108'>1109</a> validate_header_arg(header)
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1110'>1111</a> io = stringify_path(io)
# -> <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1112'>1113</a> return _parse(
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1113'>1114</a>     flavor=flavor,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1114'>1115</a>     io=io,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1115'>1116</a>     match=match,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1116'>1117</a>     header=header,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1117'>1118</a>     index_col=index_col,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1118'>1119</a>     skiprows=skiprows,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1119'>1120</a>     parse_dates=parse_dates,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1120'>1121</a>     thousands=thousands,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1121'>1122</a>     attrs=attrs,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1122'>1123</a>     encoding=encoding,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1123'>1124</a>     decimal=decimal,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1124'>1125</a>     converters=converters,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1125'>1126</a>     na_values=na_values,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1126'>1127</a>     keep_default_na=keep_default_na,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1127'>1128</a>     displayed_only=displayed_only,
#    <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=1128'>1129</a> )
#
# File ~\anaconda3\envs\ds\lib\site-packages\pandas\io\html.py:915, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=912'>913</a> retained = None
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=913'>914</a> for flav in flavor:
# --> <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=914'>915</a>     parser = _parser_dispatch(flav)
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=915'>916</a>     p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=917'>918</a>     try:
#
# File ~\anaconda3\envs\ds\lib\site-packages\pandas\io\html.py:864, in _parser_dispatch(flavor)
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=861'>862</a> if flavor in ("bs4", "html5lib"):
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=862'>863</a>     if not _HAS_HTML5LIB:
# --> <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=863'>864</a>         raise ImportError("html5lib not found, please install it")
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=864'>865</a>     if not _HAS_BS4:
#     <a href='file:///c%3A/Users/HP/anaconda3/envs/ds/lib/site-packages/pandas/io/html.py?line=865'>866</a>         raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it

# %% [markdown]
# **MINI CHALLENGE #2:**
# - **Write a code that uses Pandas to read tabular US retirement data**
# - **You can use data from here: https://www.ssa.gov/oact/progdata/nra.html**

# %% [markdown]
# # 3. PANDAS OPERATIONS

# %%
# Let's define a dataframe as follows:

# %%
# Pick certain rows that satisfy a certain criteria

# %%
# Delete a column from a DataFrame

# %% [markdown]
# **MINI CHALLENGE #3:**
# - **Using "bank_client_df" DataFrame, leverage pandas operations to only select high networth individuals with minimum $5000**
# - **What is the combined networth for all customers with 5000+ networth?**

# %% [markdown]
# # 4. PANDAS WITH FUNCTIONS

# %%
# Let's define a dataframe as follows:

# %%
# Define a function that increases all clients networth (stocks) by a fixed value of 10% (for simplicity sake)

# %%
# You can apply a function to the DataFrame

# %% [markdown]
# **MINI CHALLENGE #4:**
# - **Define a function that doubles stock prices and adds $100**
# - **Apply the function to the DataFrame**
# - **Calculate the updated total networth of all clients combined**

# %% [markdown]
# # 5. SORTING AND ORDERING

# %%
# Let's define a dataframe as follows:

# %%
# You can sort the values in the dataframe according to number of years with bank

# %%
# Note that nothing changed in memory! you have to make sure that inplace is set to True

# %%
# Set inplace = True to ensure that change has taken place in memory

# %%
# Note that now the change (ordering) took place

# %% [markdown]
# **MINI CHALLENGE #5:**
# - **Sort customers by networth instead of years with bank. Make sure to update values in-memory.**

# %% [markdown]
# # 6. CONCATENATING AND MERGING WITH PANDAS

# %% [markdown]
# Check this out: https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
# Creating a dataframe from a dictionary
# Let's define a dataframe with a list of bank clients with IDs = 1, 2, 3, 4, 5

# %%
# Let's define another dataframe for a separate list of clients (IDs = 6, 7, 8, 9, 10)

# %%
# Let's assume we obtained additional information (Annual Salary) about our bank customers 
# Note that data obtained is for all clients with IDs 1 to 10

# %%
# Let's concatenate both dataframes #1 and #2
# Note that we now have client IDs from 1 to 10

# %%
# Let's merge all data on 'Bank Client ID'

# %% [markdown]
# **MINI CHALLENGE #6:**
# - **Let's assume that you became a new client to the bank**
# - **Define a new DataFrame that contains your information such as client ID (choose 11), first name, last name, and annual salary.**
# - **Add this new dataframe to the original dataframe "bank_df_all".**

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # MINI CHALLENGE SOLUTIONS

# %% [markdown]
# **MINI CHALLENGE #1 SOLUTION:**
# - **A porfolio contains a collection of securities such as stocks, bonds and ETFs. Define a dataframe named 'portfolio_df' that holds 3 different stock ticker symbols, number of shares, and price per share (feel free to choose any stocks)**
# - **Calculate the total value of the porfolio including all stocks**

# %%
portfolio_df = pd.DataFrame({'stock ticker symbols':['AAPL', 'AMZN', 'T'],
                             'price per share [$]':[3500, 200, 40], 
                             'Number of stocks':[3, 4, 9]})
portfolio_df

# %%
stocks_dollar_value = portfolio_df['price per share [$]'] * portfolio_df['Number of stocks']
print(stocks_dollar_value)
print('Total portfolio value = {}'.format(stocks_dollar_value.sum()))

# %% [markdown]
# **MINI CHALLENGE #2 SOLUTION:**
# - **Write a code that uses Pandas to read tabular US retirement data**
# - **You can use data from here: https://www.ssa.gov/oact/progdata/nra.html**

# %%
# Read tabular data using read_html
retirement_age_df = pd.read_html('https://www.ssa.gov/oact/progdata/nra.html')
retirement_age_df

# %% [markdown]
# **MINI CHALLENGE #3 SOLUTION:**
# - **Using "bank_client_df" DataFrame, leverage pandas operations to only select high networth individuals with minimum $5000**
# - **What is the combined networth for all customers with 5000+ networth?**

# %%
df_high_networth = bank_client_df[ (bank_client_df['Net worth [$]'] >= 5000) ]
df_high_networth

# %%
df_high_networth['Net worth [$]'].sum()

# %% [markdown]
# **MINI CHALLENGE #4 SOLUTION:**
# - **Define a function that doubles stock prices and adds $100**
# - **Apply the function to the DataFrame**
# - **Calculate the updated total networth of all clients combined**

# %%
def networth_update(balance):
    return balance * 2 + 100 # assume that stock prices increased by 10%

# %%
# You can apply a function to the DataFrame 
results = bank_client_df['Net worth [$]'].apply(networth_update)
results

# %%
results.sum()

# %% [markdown]
# **MINI CHALLENGE #5 SOLUTION:**
# - **Sort customers by networth instead of years with bank. Make sure to update values in-memory.**

# %%
# You can sort the values in the dataframe according to number of years with bank
bank_client_df.sort_values(by = 'Net worth [$]', inplace = True) 
bank_client_df

# %% [markdown]
# **MINI CHALLENGE #6 SOLUTION:**
# - **Let's assume that you became a new client to the bank**
# - **Define a new DataFrame that contains your information such as client ID (choose 11), first name, last name, and annual salary.**
# - **Add this new dataframe to the original dataframe "bank_df_all".**

# %%
new_client = {
        'Bank Client ID': ['11'],
        'First Name': ['Ry'], 
        'Last Name': ['Aly'],
        'Annual Salary [$/year]' : [1000]}
new_client_df = pd.DataFrame(new_client, columns = ['Bank Client ID', 'First Name', 'Last Name', 'Annual Salary [$/year]'])
new_client_df

# %%
new_df = pd.concat([bank_df_all, new_client_df], axis = 0)
new_df
